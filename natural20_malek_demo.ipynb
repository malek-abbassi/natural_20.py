# %%
from gymnasium import make

from samples.llm_interface import GPT4Interfacer

MAX_EPISODES = 20

# Initialize the environment
env = make("dndenv-v0", root_path="templates", render_mode="ansi")
observation, info = env.reset(seed=42)

# Initialize your language model interfacer
prompt = GPT4Interfacer(debug=True)

# Select an action based on the initial state
action = prompt.select_action_for_state(observation, info)
print(f"Selected action: {action}")

terminal = False
episode = 0
while not terminal and episode < MAX_EPISODES:
    episode += 1
    observation, reward, terminal, truncated, info = env.step(action)
    if not terminal and not truncated:
        print(env.render())
        action = prompt.select_action_for_state(observation, info)
        print(f"Selected action: {action}")

    if terminal or truncated:
        print(f"Reward: {reward}")
        break
# Out:
# /home/thomas/Documents/ENS/IAS/S2/Neural Networks/DandLLM/natural_20.py/samples/llm_interface.py:327: SyntaxWarning: invalid escape sequence '\d'
#   regex = "\d"
# Setting up attributes for Krulzarbar with max hp: d6(1 + 5)=6
# Failed to initialize LLM: OpenAI API key is required. Set it as an environment variable OPENAI_API_KEY or pass it directly.
# Setting up attributes for gabba with max hp: d6(4 + 5)=9
# Setting up attributes for Gorrak with max hp: d6(6 + 4)=10
# Setting up attributes for Hrukrak with max hp: d8(4 + 6) + 2=12
# Setting up attributes for klarg with max hp: d8(6 + 6 + 5 + 1 + 8) + 5=31
# Setting up attributes for Brakbogdash with max hp: d6(3 + 6)=9
# Setting up attributes for Wolf with max hp: d8(6 + 4) + 2=12
# Setting up attributes for Gorganzug with max hp: d8(2 + 4) + 2=8
# Setting up attributes for Brakgarrog with max hp: d6(6 + 3)=9
# Setting up attributes for Wolf with max hp: d8(3 + 6) + 2=11
# Setting up attributes for Krulzug with max hp: d6(6 + 6)=12
# Setting up attributes for Dargturdash with max hp: d6(6 + 2)=8
# Setting up attributes for Vrogmokzug with max hp: d6(6 + 6)=12
# Setting up attributes for Rokraggor with max hp: d6(1 + 3)=4
# Setting up attributes for Hoggrok with max hp: d10(2 + 4 + 10 + 6 + 4 + 8 + 7) + 21=62
# Setting up attributes for Thakzug with max hp: d6(2 + 2)=4
# Setting up attributes for Dargmak with max hp: d6(5 + 4)=9
# /home/thomas/.conda/envs/dandllm/lib/python3.13/site-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /home/thomas/Documents/ENS/IAS/S2/Neural Networks/DandLLM/natural_20.py/samples/llm_interface.py:327: SyntaxWarning: invalid escape sequence '\d'
#   regex = "\d"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       9 observation, info = env.reset(seed=42)
#      11 # Initialize your language model interfacer
# ---> 12 prompt = GPT4Interfacer(debug=True)
#      14 # Select an action based on the initial state
#      15 action = prompt.select_action_for_state(observation, info)
#
# File ~/Documents/ENS/IAS/S2/Neural Networks/DandLLM/natural_20.py/samples/llm_interface.py:196, in GPT4Interfacer.__init__(self, variant, debug, api_key, base_url, tools, explain, weapon_mappings, max_retries)
#     194     api_key = os.getenv("OPENAI_API_KEY")
#     195     if api_key is None:
# --> 196         raise ValueError("Please set the OPENAI_API_KEY environment variable")
#     198 self.variant = variant
#     199 self.debug = debug
#
# ValueError: Please set the OPENAI_API_KEY environment variable
